# %%
# !git clone https://github.com/clementgr/stain-normalization.git
# !rm -r /content/sample_data
# Out:
# Cloning into 'stain-normalization'...
# remote: Enumerating objects: 192, done.
# remote: Counting objects: 100% (192/192), done.
# remote: Compressing objects: 100% (141/141), done.
# remote: Total 192 (delta 107), reused 123 (delta 45), pack-reused 0
# Receiving objects: 100% (192/192), 40.40 KiB | 10.10 MiB/s, done.
# Resolving deltas: 100% (107/107), done.

# %%
import os
os.chdir('stain-normalization')

# %%
# !sh scripts/train_test_data_download.sh
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1640FtfGv1gQ3gdsEo5chEWb23qmJlhXm
# To: /content/stain-normalization/trainA.zip
# 548MB [00:04, 124MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-9D2Yn_JDprzv_VTugFfXKsaah7ECEaN
# To: /content/stain-normalization/trainB.zip
# 526MB [00:03, 164MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-BHbhFQAMCuISqRviytFYvyXK1O7AdCM
# To: /content/stain-normalization/testA.zip
# 137MB [00:02, 59.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-BoubBOfmie0ZBJtkIfZOyuz4mtSoSpi
# To: /content/stain-normalization/testB.zip
# 131MB [00:07, 17.3MB/s]

# %%
# !sh scripts/checkpoint_download.sh
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1QgmA8FHDv-oDcBJXeQ8Ql99WAcb0tnyj
# To: /content/stain-normalization/checkpoints/pretrained.zip
# 1.68GB [00:43, 38.8MB/s]

# %% [markdown]
# train

# %%
# !python train.py --config config/train_config.json
# Out:
# ------------ Options -------------
# aicha_loss: False
# batchSize: 4
# beta1: 0.5
# checkpoints_dir: checkpoints
# continue_train: False
# cropSize: 256
# dataroot: data
# dataset_mode: unaligned
# display_id: 0
# display_port: 0
# display_single_pane_ncols: 0
# display_winsize: 256
# epoch_count: 1
# gpu_ids: [0]
# identity: 0.5
# init_type: normal
# initialized: True
# input_nc: 3
# isTrain: True
# lambda_A: 10.0
# lambda_Aicha: 10.0
# lambda_B: 10.0
# loadSize: 256
# lr: 0.0002
# lr_decay_iters: 50
# lr_policy: step
# max_dataset_size: 100000
# model: cycle_gan
# nThreads: 1
# n_layers_D: 3
# name: experiment_name
# ndf: 64
# ngf: 64
# niter: 10
# niter_decay: 10
# no_dropout: False
# no_flip: False
# no_html: False
# no_lsgan: False
# norm: instance
# output_nc: 3
# phase: train
# pool_size: 50
# print_freq: 100
# resize_or_crop: crop
# save_epoch_freq: 1
# save_latest_freq: 5000
# save_log: True
# serial_batches: False
# shuffle: True
# update_html_freq: 1000
# which_direction: AtoB
# which_epoch: latest
# which_model_netD: basic
# which_model_netG: resnet_9blocks
# -------------- End ----------------
# dataset UnalignedDataset was created
# CustomDatasetDataLoader
# #training images = 3648
# cycle_gan
# initialization method [normal]
# initialization method [normal]
# initialization method [normal]
# initialization method [normal]
# model CycleGAN was created
# Train - Epoch: 1:   2%|▍                   | 76/3648 [00:42<33:23,  1.78 imgs/s]
# Traceback (most recent call last):
#   File "train.py", line 67, in <module>
#     model.optimize_parameters()
#   File "/content/stain-normalization/models.py", line 296, in optimize_parameters
#     self.backward_G()
#   File "/content/stain-normalization/models.py", line 267, in backward_G
#     loss_G.backward()
#   File "/usr/local/lib/python3.7/dist-packages/torch/tensor.py", line 221, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph)
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py", line 132, in backward
#     allow_unreachable=True)  # allow_unreachable flag
# KeyboardInterrupt

# %% [markdown]
# inference

# %%
# !python inference.py --config config/inference_config.json
# Out:
# remove existing result dir? y
# #inference images = 912
# cycle_gan
# initialization method [normal]
# initialization method [normal]
# model CycleGAN_inference was created
# how_many: 4
# --- 1.84 seconds ---
